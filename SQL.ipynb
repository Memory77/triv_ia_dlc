# %%
import sqlite3

# Connexion à la base de données
conn = sqlite3.connect('triv_ia_dlc.db')
with open('dump.sql', 'w') as f:
    for ligne in conn.iterdump():
        f.write('%s\n' % ligne)

# Fermeture de la connexion
conn.close()

# %%
import os

os.system('cat dump.sql | grep INSERT > INSERT.sql')
# Out:
# 0
